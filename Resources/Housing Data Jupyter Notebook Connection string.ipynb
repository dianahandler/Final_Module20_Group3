# %%
import pandas as pd
import psycopg2 as pg
import pandas.io.sql as psql
conn = pg.connect(database="Housing_ProjectDB",user="postgres", password="password")
##Changed actually password to placeholder "password after running"
pd.set_option('display.max_columns', None)
##shows all the available columns
df = pd.read_sql('SELECT * FROM House_data_complete', conn)
df.head()

## Connection string information found on stack overflow
# Out:
#          zpid    city          streetaddress  zipcode  \
# 0   111373431  austin   14424 Lake Victor Dr    78660
# 1   120900430  austin     1104 Strickling Dr    78660
# 2  2084491383  austin    1408 Fort Dessau Rd    78660
# 3   120901374  austin     1025 Strickling Dr    78660
# 4    60134862  austin  15005 Donna Jane Loop    78660
#
#                                          description   latitude  longitude  \
# 0  14424 Lake Victor Dr, Pflugerville, TX 78660 i...  30.430632  -97.66308
# 1  Absolutely GORGEOUS 4 Bedroom home with 2 full...  30.432673  -97.66170
# 2  Under construction - estimated completion in A...  30.409748  -97.63977
# 3  Absolutely darling one story home in charming ...  30.432112  -97.66166
# 4  Brimming with appeal & warm livability! Sleek ...  30.437368  -97.65686
#
#    propertytaxrate  garagespaces  hasassociation  hascooling  hasgarage  \
# 0             1.98             2               1           1          1
# ...
